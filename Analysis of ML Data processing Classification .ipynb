# %% [markdown]
# ### Correlation and Covariance

# %% [markdown]
# ###### Both Correlation and covarience indicate the direction of linear relationship between variables. Covarience indicates strength as well as the direction of linear relationship among variables. While Correlation measures direction of linear relationship two variables. Correlation is a function of covariance.
#
# ###### If we consider two vector and perform their dot product the cosine angle is the correlation and the result of the dot product is the covariance.

# %% [markdown]
# ###### the correlation coefficient of two variables by dividing the covariance of these variables by the product of the standard deviations of the same values.

# %% [markdown]
# ###### When you divide the covariance values by the standard deviation, it essentially scales the value down to a limited range of -1 to +1. This is precisely the range of the correlation values.

# %% [markdown]
# #### Cov(x,y)=Sum((x-mean(x))(y-mean(y))) / n

# %% [markdown]
# ###### Cov(y,y)= Var(y) = (std(y))^2

# %% [markdown]
# ##### Var(y)= Sum((y-mean(y))^2)) / n

# %% [markdown]
# ##### Correlation=corr(x,y)= Cov(x,y) / std(x).std(y)

# %% [markdown]
# The values of the correlation coefficient can range from -1 to +1. The closer it is to +1 or -1, the more closely are the two variables are related. The positive sign signifies the direction of the correlation i.e. if one of the variables increases, the other variable is also supposed to increase.

# %% [markdown]
# As we see from the formula of covariance, it assumes the units from the product of the units of the two variables. On the other hand, correlation is dimensionless. It is a unit-free measure of the relationship between variables. This is because we divide the value of covariance by the product of standard deviations which have the same units. The value of covariance is affected by the change in scale of the variables. If all the values of the given variable are multiplied by a constant and all the values of another variable are multiplied, by a similar or different constant, then the value of covariance also changes. However, on doing the same, the value of correlation is not influenced by the change in scale of the values. Another difference between covariance and correlation is the range of values that they can assume. While correlation coefficients lie between -1 and +1, covariance can take any value between -∞ and +∞.

# %% [markdown]
# ### Variance and Skewness

# %% [markdown]
# ###### Variance is extremely important as a means to visualise and understand the data being considered.
#
# ###### The point of statistics is to represent some situation (quantified, ostensibly, in a data set) in an efficient, concise, and clear manner. What the “typical” member of the set looks like, and how similar the items are.

# %% [markdown]
# ###### The variance is a measure of how dispersed or spread out the set is, something that the “average” (mean or median) is not designed to do. If I tell you a data set has a variance of zero, for example, you know that every member of it is the same. If the variance is high, especially as a ratio to the mean, that tells you that the data have some very large dis-similarities amongst its members.

# %% [markdown]
# ###### If the variance is very low, we are basically getting all similar kinds of data from that feature or feature set. The machine learning usually works on dissimilarities in behaviour of Data Points among different classes

# %% [markdown]
# ###### So, if it is very low points are expected to cluster around the same points which cause them to be very hard to diffrerentiate. So variance is often regarded as the information in case of ML datasets

# %% [markdown]
# ###### The third moment is the “skewness.” It is itself a description of how balanced the data are. Do they cluster in mass to the left with a few points way off to the right, or are they symmetrical. A data set that is equally distributed to the left and right has zero skewness

# %% [markdown]
# ###### Skewness also plays a major role on decieding how distributed is the data. It is often seen that data is highly present at the lower scale side than the lower scale side. This can be a problem for plotting and the features capability two differentiate between different classes.

# %% [markdown]
# ### ROC- AUC Curve

# %% [markdown]
# ###### This performance measurement is used for classification jobs. It is used to vizualize the performances of classification problems. We use AUC (Area Under The Curve) ROC (Receiver Operating Characteristics).

# %% [markdown]
# ###### In each classification problem, there is a classification threshold which is used to decide to which class a particular sample belongs to based on a prediction percentage. Now, if we vary the threshold of course the predictions change as the cutoffs change. So, the False Positive Rates and the True Positive Rates also change. This variation is shown by the ROC- AUC curve with different changeing threshold

# %% [markdown]
# ###### AUC stands for "Area under the ROC Curve." That is, AUC measures the entire two-dimensional area underneath the entire ROC curve

# %% [markdown]
# ###### AUC provides an aggregate measure of performance across all possible classification thresholds. So, more the AUC more is chance that the model labels the classes correctly. So, more is the accuracy

# %% [markdown]
# ###### TPR / Sensitivity = TP / (TP+FN)

# %% [markdown]
# ###### Specificity = TN / (TN+FP)

# %% [markdown]
# ###### FPR = 1 - Specificity : FP / (TN+FP)

# %% [markdown]
# ###### An excellent model has AUC near to the 1 which means it has good measure of separability. A poor model has AUC near to the 0 which means it has worst measure of separability. In fact it means it is reciprocating the result. It is predicting 0s as 1s and 1s as 0s. And when AUC is 0.5, it means model has no class separation capacity whatsoever.

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Case 1:

# %% [markdown]
# ![Ideal_ROC.png](attachment:Ideal_ROC.png)

# %% [markdown]
# ![Ideal_Curve.png](attachment:Ideal_Curve.png)

# %% [markdown]
# ###### This is the ideal case here the model predicts every points correctly. In actual data the positive and negative classes are disjoint sets i.e, a point can either be true positive or be true negative but can't be both. Here we can see that the model covers and classifies all the points correctly. So, the area under curve is the full 2D box area i.e, 1 and accuracy is 100%

# %% [markdown]
# #### Case 2:

# %% [markdown]
# ![Actual_ROC.png](attachment:Actual_ROC.png)

# %% [markdown]
# ![Actual_curve.png](attachment:Actual_curve.png)

# %% [markdown]
# ###### These graphs show the actual behaviour of the models. Here we can see there is a over lap portion where the model predicts a few sample wrong i.e, samples Positive class as negative class and vice versa. The smaller the overlap portion higher the accuracy of the model. Here we can see that the AUC is 0.7 not 1

# %% [markdown]
# #### Case 3:   NO SKILL CLASSIFIER

# %% [markdown]
# ![Naive_ROC.png](attachment:Naive_ROC.png)

# %% [markdown]
# ![Naive_curve.png](attachment:Naive_curve.png)

# %% [markdown]
# ###### This is a case where the model has basically not learnt anything. So, it keeps predicting two class on a equal basis. So, half the time it classifies correct half time it is wrong.

# %% [markdown]
# #### Case 4:

# %% [markdown]
# ![Wrong_roc.png](attachment:Wrong_roc.png)

# %% [markdown]
# ![Wrong_curve.png](attachment:Wrong_curve.png)

# %% [markdown]
# ###### In this cases, the model classifies all positive classes as negatives and negative classes as positives. So, does a total wrong classification. So, the AUC score is 0, the accuracy is 100%

# %% [markdown]
# ### Precision Recall Curve

# %% [markdown]
# ##### These measures are also useful in applied machine learning for evaluating binary classification models.

# %% [markdown]
# #### Precision= TP / (TP +FP)

# %% [markdown]
# #### Recall = TP / (TP + FN)

# %% [markdown]
# ##### Sensitivity = True Positives / (True Positives + False Negatives)

# %% [markdown]
# #### Reviewing both precision and recall is useful in cases where there is an imbalance in the observations between the two classes.

# %% [markdown]
# ###### If the data set has too many instances of positive class and almost no instances of negative class then the model will be proned to predict positive class and so more false positive hence low precision.
#
# ###### If the data set has too many instances of negative class and almost no instances of positive class then the model will be proned to predict negative class and so more false negative hence low recall.

# %% [markdown]
# ###### Now this doesnot take into consideration true negatives. So only positive class are concerned. Now these graphs have a no skill classifier base line which serves as the reference. It is a straight line at 0.5. The curve is measured on its basis like if the model classifies best it is a convex and away from the base line, else it is closer

# %% [markdown]
# ![Precision_recall.png](attachment:Precision_recall.png)

# %% [markdown]
# ##### Precision Recall Curve
