# %%
import pandas as pd

# %%
df=pd.read_csv('datasets_180_408_data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df=df.drop(['Unnamed: 32'],axis=1)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Checking Correlations

# %%
import seaborn as sb
import matplotlib.pyplot as plt
C_mat = df.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# ###### It shows correlation of one feature with other -:- Covariance is used

# %%
df.hist(figsize = (35,35))
plt.show()

# %% [markdown]
# ###### Histograms shows the frequency Distribution of each feature

# %% [markdown]
# ### Obtaining train and test data

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df=df.drop(['id'],axis=1)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
Y=pd.DataFrame(df['diagnosis'].values,columns=['diagnosis'])

# %%
X=df.drop(['diagnosis'],axis=1)

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scale=scaler.fit(X)

# %%
X_scaled=scaler.transform(X)

# %%
X_scaled
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %% [markdown]
# ##### Standard Scaling: (Element - mean) / Standard Deviation -:- Between 0 to 1

# %% [markdown]
# ###### Scaling is important because if we have a feture with very large value other with very small then the large value will have more imortance or weightage because biwi

# %% [markdown]
# #### Checking Distribution of target

# %%
import matplotlib.pyplot as plt
feature = "diagnosis"
ax = df[feature].value_counts().plot(kind='bar',
                                    figsize=(10,10), 
                                    color='blue')
ax.set_xlabel(feature, fontsize=20)
ax.set_ylabel("Count",fontsize=20)
# Out:
# Text(0, 0.5, 'Count')

# %%
df[feature].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ### Checking Each Feature

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
import seaborn as sns
sns.distplot(df['radius_mean']);

# %%
df['radius_mean'].describe()
# Out:
# count    569.000000
# mean      14.127292
# std        3.524049
# min        6.981000
# 25%       11.700000
# 50%       13.370000
# 75%       15.780000
# max       28.110000
# Name: radius_mean, dtype: float64

# %%
import seaborn as sns
sns.distplot(df['texture_mean']);

# %%
df['texture_mean'].describe()
# Out:
# count    569.000000
# mean      19.289649
# std        4.301036
# min        9.710000
# 25%       16.170000
# 50%       18.840000
# 75%       21.800000
# max       39.280000
# Name: texture_mean, dtype: float64

# %%
import seaborn as sns
sns.distplot(df['perimeter_mean']);

# %% [markdown]
# ### Handling Skewed Data

# %%
import seaborn as sns
sns.distplot(df['fractal_dimension_se']);

# %%
df['fractal_dimension_se'].describe()
# Out:
# count    569.000000
# mean       0.003795
# std        0.002646
# min        0.000895
# 25%        0.002248
# 50%        0.003187
# 75%        0.004558
# max        0.029840
# Name: fractal_dimension_se, dtype: float64

# %%
import numpy as np
df['new_fractal_dimension_se']=np.log(df['fractal_dimension_se'].values)

# %%
import seaborn as sns
sns.distplot(df['new_fractal_dimension_se']);

# %% [markdown]
# ##### If data is skewed often happens that some class is majorly represented and others are very poorly represented which causes non-uniformity and lower performances taking log of the feature and using it often solves the problem

# %%
df=df.drop(['fractal_dimension_se'],axis=1)

# %%
import seaborn as sns
sns.distplot(df['area_se']);

# %%
import numpy as np
df['new_area_se']=np.log(df['area_se'].values)

# %%
import seaborn as sns
sns.distplot(df['new_area_se']);

# %%
df=df.drop(['area_se'],axis=1)

# %%
import seaborn as sns
sns.distplot(df['compactness_se']);

# %%
import seaborn as sns
sns.distplot(df['concavity_se']);

# %%
import numpy as np

df['new_conacvity_se']=np.log(df['concavity_se'].values)
# Out:
# /home/abhijit/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# #### Runtime Warning log(0) is encountered So check the description first

# %%
import numpy as np

df['new_conacvity_se']=np.log(df['concavity_se'].values+0.001)

# %% [markdown]
# ##### The 0.001 term helps to avoid error

# %%
import seaborn as sns
sns.distplot(df['new_conacvity_se']);

# %% [markdown]
# ### Relaionship between Numerical values

# %%
data = pd.concat([df['radius_mean'], df['texture_mean']], axis=1)
data.plot.scatter(x='texture_mean', y='radius_mean');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
data = pd.concat([df['radius_mean'], df['new_conacvity_se']], axis=1)
data.plot.scatter(x='new_conacvity_se', y='radius_mean',);
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst',
#        'new_fractal_dimension_se', 'new_area_se', 'new_conacvity_se'],
#       dtype='object')

# %% [markdown]
# ##### No correlations exist

# %%
import seaborn as sns
sns.set()
cols = ['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'smoothness_se']
sns.pairplot(df[cols], size = 2.5)
plt.show();
# Out:
# /home/abhijit/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Pair plot: Done only for numerical values. The diagonal element shows the distribution of the feature and other graph shows the distribution of the two features using scatter plot

# %%
data = pd.concat([df['radius_se'], df['area_mean']], axis=1)
data.plot.scatter(x='area_mean', y='radius_se');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ##### Few have linear correlation Few have non linear correlation

# %%
data = pd.concat([df['radius_se'], df['diagnosis']], axis=1)
f, ax = plt.subplots(figsize=(10, 10))
fig = sns.boxplot(x='diagnosis', y="radius_se", data=data)
fig.axis(ymin=0, ymax=3.0);

# %% [markdown]
# ###### For Categorical data we can easily found the outliers in the data and remove them or restrict them to a limit. This increases model performances

# %%
data = pd.concat([df['texture_mean'], df['diagnosis']], axis=1)
f, ax = plt.subplots(figsize=(10, 10))
fig = sns.boxplot(x='diagnosis', y="texture_mean", data=data)

# %% [markdown]
# ##### We can see several outliers

# %% [markdown]
# #### The upper and lower dashes are higest and lowest values. The solid region between the 1st and 3rd quartiles.

# %%
import matplotlib.pyplot as plt
values=['M','B']

means=[]
for value in values:
    df_k=df[df['diagnosis']==value]
    
    means.append(np.mean(df_k['radius_mean'][:]))
langs = ['M', 'B']
df = pd.DataFrame({'Type':langs, 'radius_mean':means})
ax = df.plot.bar(x='Type', y='radius_mean', rot=0)

# %% [markdown]
# ##### This kind of plots help to mark a behavioural difference in numerical features wrt to categorical once.

# %%
import seaborn as sns
sns.set(style="whitegrid")

ax = sns.barplot(x="diagnosis", y="area_mean", data=df)

# %% [markdown]
# ###### This does the thing automatically

# %%
g = sns.lmplot('radius_mean',"area_mean", df);

# %% [markdown]
# #### This shows a linear relation between the two features more the mean radius more the area
